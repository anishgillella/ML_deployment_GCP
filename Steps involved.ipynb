# %% [markdown]
# ### Enabling APIs on GCP console
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Creating a dataset in the mode
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Labelling the Dataset
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Finetuning the dataset further to train with better images
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Training the model
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Finished training model
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Deploying the model to endpoints to test it
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Testing the image
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Test 3
#
# ![image.png](attachment:image.png)
